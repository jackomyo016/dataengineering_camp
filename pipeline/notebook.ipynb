# %%
import pandas as pd

# %%
data = [
    (1, "Albert Park", "Merbourne", "Australia", 5.303, 84.1, 24, 2004),
    (2, "Sepang International Circuit", "Kuala Lumpur", "Malaysia", 5.543, 94.2, 25, 2004),
    (3, "Bahrain International Circuit", "Sakhir", "Bahrain", 5.412, 91.4, 26, 2005),
    (4, "Shanghai International Circuit", "Shangai", "China", 5.451, 92.2, 24, 2004),
    (5, "Circuit de Barcelona-Catalunya", "Barcelona", "Spain", 4.655, 82.7, 18, 2008),
    (6, "Circuit de Monaco", "Monaco", "Monaco", 3.340, 74.4, 24, 2004),
    (7, "Circuit Gilles-Villeneuve", "Montréal", "Canada", 4.361, 74.6, 27, 2004),
    (8, "Red Bull Ring", "Spielberg", "Austria", 4.326, 68.3, 24, 2003),
    (9, "Silverstone circuit", "Silverstone", "Great Britain", 5.891, 93.4, 28, 2013),b
    (10, "Hockenheimring", "Hockenheim", "Germany", 4.574, 74.8, 18, 2004),
    (11, "Hungaroring", "Budapest", "Hungary", 4.381, 79.1, 24, 2004),
    (12, "Circuit de Spa-Francorchamps", "Spa-Francorchamps", "Belgium", 7.004, 107.3, 23, 2009),
    (13, "Autodromo di Monza", "Monza", "Italy", 5.793, 82.7, 27, 2004),
    (14, "Marina Bay Street Circuit", "Singapore", "Singapore", 5.065, 109.6, 23, 2013),
    (15, "Suzuka circuit", "Suzuka", "Japan", 5.807, 91.5, 18, 2005),
    (16, "Sochi Autodrom", "Sochi", "Russia", 5.853, None, None, None),
    (17, "Circuit of The Americas", "Austin", "United States", 5.513, 99.3, 23, 2012),
    (18, "Autodromo Jose Carlos Pace", "São Paulo", "Brazil", 4.309, 71.5, 25, 2004),
    (19, "Yas Marina circuit", "Yas Marina", "Abu Dhabi", 5.554, 100.3, 23, 2009),
    (20, "Nürburgring", "Nürburg", "Germany", 5.148, 89.4, 9, 2013),
    (21, "Korea International Circuit", "Mokpo", "Korea", 5.621, 95.6, 23, 2010),
    (22, "Buddh International Circuit", "Greater Noida", "India", 5.125, 84.1, 23, 2013),
]

columns = [
    "circuitID",
    "cName",
    "cCity",
    "cCountry",
    "cLength",
    "cLapRec",
    "cDrivRec",
    "cYearRec",
]

circuit = pd.DataFrame(data, columns=columns)

circuit = circuit.astype({
    "circuitID": "int64",
    "cName": "string",
    "cCity": "string",
    "cCountry": "string",
    "cLength": "float64",
    "cLapRec": "Float64",
    "cDrivRec": "Int64",
    "cYearRec": "Int64",
})

# %%
import pandas as pd

data = [
    (1, "Fernando", "Alonso", "1981-07-29", None, "Spain", "M"),
    (2, "Jules", "Bianchi", "1989-08-03", None, "France", "M"),
    (3, "Valtteri", "Bottas", "1989-08-28", None, "Finland", "M"),
    (4, "Jenson", "Button", "1980-01-19", None, "Great Britain", "M"),
    (5, "Max", "Chilton", "1991-04-21", None, "Great Britain", "M"),
    (6, "Marcus", "Ericsson", "1990-09-02", None, "Sweden", "M"),
    (7, "Romain", "Grosjean", "1986-04-17", None, "France", "M"),
    (8, "Esteban", "Gutierrez", "1991-08-05", None, "Mexico", "M"),
    (9, "Lewis", "Hamilton", "1985-01-07", None, "Great Britain", "M"),
    (10, "Nico", "Hulkenberg", "1985-06-27", None, "Germany", "M"),
    (11, "Kamui", "Kobayashi", "1986-09-17", None, "Japan", "M"),
    (12, "Daniil", "Kvyat", "1994-04-26", None, "Russia", "M"),
    (13, "André", "Lotterer", "1981-11-19", None, "Germany", "M"),
    (14, "Kevin", "Magnussen", "1992-10-05", None, "Denmark", "M"),
    (15, "Pastor", "Maldonado", "1985-03-09", None, "Venezuela", "M"),
    (16, "Felipe", "Massa", "1981-04-25", None, "Brazil", "M"),
    (17, "Sergio", "Pérez", "1990-01-26", None, "Mexico", "M"),
    (18, "Kimi", "Räikkönen", "1979-10-17", None, "Finland", "M"),
    (19, "Daniel", "Ricciardo", "1989-07-01", None, "Australia", "M"),
    (20, "Nico", "Rosberg", "1985-06-27", None, "Germany", "M"),
    (21, "Adrian", "Sutil", "1983-01-11", None, "Germany", "M"),
    (22, "Jean-Éric", "Vergne", "1990-04-25", None, "France", "M"),
    (23, "Sebastian", "Vettel", "1987-07-03", None, "Germany", "M"),
    (24, "Michael", "Schumacher", "1969-01-03", None, "Germany", "M"),
    (25, "Juan Pablo", "Montoya", "1975-09-20", None, "Colombia", "M"),
    (26, "Pedro", "de la Rosa", "1971-02-24", None, "Spain", "M"),
    (27, "Rubens", "Barrichello", "1972-05-23", None, "Brazil", "M"),
    (28, "Mark", "Webber", "1976-08-27", None, "Australia", "M"),
    (29, "Sébastien", "Buemi", "1988-10-31", None, "Switzerland", "M"),
    (30, "António", "Félix da Costa", "1991-08-31", None, "Portugal", "M"),
    (31, "Pascal", "Wehrlein", "1994-10-18", None, "Germany", "M"),
    (32, "Marc", "Gené", "1974-03-29", None, "Spain", "M"),
    (33, "Davide", "Rigon", "1986-08-26", None, "Italy", "M"),
    (34, "Charles", "Pic", "1990-02-15", None, "France", "M"),
    (35, "Nicolas", "Prost", "1981-08-18", None, "France", "M"),
    (36, "Stoffel", "Vandoorne", "1992-03-26", None, "Belgium", "M"),
    (37, "Daniel", "Juncadella", "1991-05-07", None, "Spain", "M"),
    (38, "Sergey", "Sirotkin", "1995-08-27", None, "Russia", "M"),
    (39, "Giedo", "Van der Garde", "1985-04-25", None, "Netherlands", "M"),
    (40, "Simona", "de Silvestro", "1988-09-01", None, "Switzerland", "F"),
    (41, "Felipe", "Nasr", "1992-08-21", None, "Brazil", "M"),
    (42, "Susie", "Wolff", "1982-12-06", None, "Great Britain", "F"),
    (43, "Alexander", "Rossi", "1991-09-25", None, "United States", "M"),
    (44, "Robin", "Frijns", "1991-08-07", None, "Netherlands", "M"),
    (45, "Nathanaël", "Berthon", "1989-07-01", None, "France", "M"),
    (46, "Julián", "Leal", "1990-05-11", None, "Colombia", "M"),
    (47, "Roberto", "Merhi", "1991-03-22", None, "Spain", "M"),
    (48, "Mika", "Häkkinen", "1968-09-28", None, "Finland", "M"),
    (49, "Jacques", "Villeneuve", "1971-04-09", None, "Canada", "M"),
    (50, "Damon", "Hill", "1960-09-17", None, "Great Britain", "M"),
    (51, "Alain", "Prost", "1955-02-24", None, "France", "M"),
    (52, "Nigel", "Mansell", "1953-08-08", None, "Great Britain", "M"),
    (53, "Ayrton", "Senna", "1960-03-21", "1994-05-01", "Brazil", "M"),
    (54, "Nelson", "Piquet", "1952-08-17", None, "Brazil", "M"),
    (55, "Niki", "Lauda", "1949-02-22", None, "Austria", "M"),
    (56, "Keke", "Rosberg", "1948-12-06", None, "Finland", "M"),
    (57, "Alan", "Jones", "1946-11-02", None, "Australia", "M"),
    (58, "Jody", "Scheckter", "1950-01-29", None, "South Africa", "M"),
    (59, "Mario", "Andretti", "1940-02-28", None, "United States", "M"),
    (60, "James", "Hunt", "1947-08-29", "1993-06-15", "Great Britain", "M"),
    (61, "Emerson", "Fittipaldi", "1946-12-12", None, "Brazil", "M"),
    (62, "Jackie", "Stewart", "1939-06-11", None, "Great Britain", "M"),
    (63, "Jochen", "Rindt", "1942-04-18", "1970-09-05", "Austria", "M"),
    (64, "Graham", "Hill", "1929-02-15", "1975-11-29", "Great Britain", "M"),
    (65, "Denny", "Hulme", "1936-06-18", "1992-10-04", "New Zealand", "M"),
    (66, "Jack", "Brabham", "1926-04-02", "2014-05-19", "Australia", "M"),
    (67, "Jim", "Clark", "1936-03-04", "1968-04-07", "Great Britain", "M"),
    (68, "John", "Surtees", "1934-02-11", None, "Great Britain", "M"),
    (69, "Phil", "Hill", "1927-04-20", "2008-08-28", "United States", "M"),
    (70, "Mike", "Hawthorn", "1929-04-10", "1959-01-22", "Great Britain", "M"),
    (71, "Juan Manuel", "Fangio", "1911-06-24", "1995-07-17", "Argentina", "M"),
    (72, "Alberto", "Ascari", "1918-07-13", "1955-05-26", "Italy", "M"),
    (73, "Giuseppe", "Farina", "1906-10-30", "1966-06-30", "Italy", "M"),
    (74, "Will", "Stevens", "1991-06-28", None, "Great Britain", "M"),
    (75, "Paul", "di Resta", "1986-04-16", None, "Great Britain", "M"),
    (76, "Heikki", "Kovalainen", "1981-10-19", None, "Finland", "M"),
    (77, "Gary", "Paffet", "1981-03-24", None, "Great Britain", "M"),
    (78, "Oliver", "Turvey", "1987-04-01", None, "Great Britain", "M"),
    (79, "Davide", "Valsecchi", "1987-01-24", None, "Italy", "M"),
    (80, "Jérôme", "D'Ambrosio", "1985-12-27", None, "Belgium", "M"),
    (81, "Brendon", "Hartley", "1989-11-10", None, "New Zealand", "M"),
    (82, "Ma", "Qing Hua", "1987-12-25", None, "China", "M"),
    (83, "Rodolfo", "González", "1986-05-14", None, "Venezuela", "M"),
]

columns = [
    "driverID",
    "dFirstName",
    "dLastName",
    "dBirthdate",
    "dDeathdate",
    "dCountry",
    "dGender",
]

driver = pd.DataFrame(data, columns=columns)

# Conversion des types
driver = driver.astype({
    "driverID": "int64",
    "dFirstName": "string",
    "dLastName": "string",
    "dCountry": "string",
    "dGender": "string",
})

# Conversion des dates
driver["dBirthdate"] = pd.to_datetime(driver["dBirthdate"])
driver["dDeathdate"] = pd.to_datetime(driver["dDeathdate"])

# %%
dtype = {
    "VendorID": "Int64",
    "passenger_count": "Int64",
    "trip_distance": "float64",
    "RatecodeID": "Int64",
    "store_and_fwd_flag": "string",
    "PULocationID": "Int64",
    "DOLocationID": "Int64",
    "payment_type": "Int64",
    "fare_amount": "float64",
    "extra": "float64",
    "mta_tax": "float64",
    "tip_amount": "float64",
    "tolls_amount": "float64",
    "improvement_surcharge": "float64",
    "total_amount": "float64",
    "congestion_surcharge": "float64"
}

parse_dates = [
    "tpep_pickup_datetime",
    "tpep_dropoff_datetime"
]

df = pd.read_csv(
    url,
    dtype=dtype,
    parse_dates=parse_dates
)

# %%
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2021-01-01 00:30:10   2021-01-01 00:36:12                1
# 1         1  2021-01-01 00:51:20   2021-01-01 00:52:19                1
# 2         1  2021-01-01 00:43:30   2021-01-01 01:11:06                1
# 3         1  2021-01-01 00:15:48   2021-01-01 00:31:01                0
# 4         2  2021-01-01 00:31:49   2021-01-01 00:48:21                1
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           2.10           1                  N           142            43
# 1           0.20           1                  N           238           151
# 2          14.70           1                  N           132           165
# 3          10.60           1                  N           138           132
# 4           4.94           1                  N            68            33
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql+psycopg://root:root@localhost:5432/formule_one')

# %%
print(pd.io.sql.get_schema(df, name='yellow_taxi_data', con=engine))
# Out:
# CREATE TABLE yellow_taxi_data (
# 	"VendorID" BIGINT,
# 	tpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	tpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	passenger_count BIGINT,
# 	trip_distance FLOAT(53),
# 	"RatecodeID" BIGINT,
# 	store_and_fwd_flag TEXT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	payment_type BIGINT,
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	congestion_surcharge FLOAT(53)
# )

# %%
df.head(n=0).to_sql(name='yellow_taxi_data', con=engine, if_exists = "replace")
# Out:
# 0

# %%
df_iter = pd.read_csv(
    url,
    dtype=dtype,
    parse_dates=parse_dates,
    iterator=True,
    chunksize=100000
)

# %%
for df_chunk in df_iter:
    df_chunk.to_sql(name='yellow_taxi_data', con=engine, if_exists = "append")
